# %%
my_dict={0:10,1:20}
my_dict[2]=30
print("Dictionary:",my_dict)
# Out:
# Dictionary: {0: 10, 1: 20, 2: 30}

# %%
dict1={0:10,1:20}
dict2={3:30,4:40}
dict3={5:50,6:60}
new_dict={}
new_dict.update(dict1)
new_dict.update(dict2)
new_dict.update(dict3)
print("Updates dictionary:",new_dict)
# Out:
# Updates dictionary: {0: 10, 1: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
my_dict={101:"Abhriaj",102:"Sahil",103:"Sumedh"}
key=int(input("Enter the key to search"))
if key in my_dict:
    print("Key exist in the dictionary")
else:
    print("Key doesn't exist in the dictionary")
# Out:
# Enter the key to search 104
# Key doesn't exist in the dictionary

# %%
my_dict={101:"Abhriaj",
         102:"Sahil",
         103:"Sumedh"}

print("Key:")
for key in my_dict:
  print(key)
print("Values")
for value in my_dict.values():
  print(value)
print("Keys and Values:")
for key,value in my_dict.items():
  print(key,value)
# Out:
# Key:
# 101
# 102
# 103
# Values
# Abhriaj
# Sahil
# Sumedh
# Keys and Values:
# 101 Abhriaj
# 102 Sahil
# 103 Sumedh

# %%
my_dict={}
for i in range(1,16):
    my_dict[i]=i**2
print("Dictionary:",my_dict)
# Out:
# Dictionary: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
my_dict={0: 10, 1: 20, 3: 30, 4: 40, 5: 50, 6: 60}
total=0
for value in my_dict.values():
    total=total+value
print("Sum of the values of dictionary =",total)
# Out:
# Sum of the values of dictionary = 210

# %%
my_dict={}
for i in range(1,6):
    my_dict[i]=str(input("Enter the name:"))
print(my_dict)
# Out:
# Enter the name: Abhiraj
# Enter the name: Sahil
# Enter the name: Sumedh
# Enter the name: Krishna
# Enter the name: Rajveer
# {1: 'Abhiraj', 2: 'Sahil', 3: 'Sumedh', 4: 'Krishna', 5: 'Rajveer'}

# %%
my_dict[6]="shriyansh"
print(my_dict)
# Out:
# {1: 'Abhiraj', 2: 'Sahil', 3: 'Sumedh', 4: 'Krishna', 5: 'Rajveer', 6: 'shriyansh'}

# %%
del my_dict[6]
print(my_dict)
# Out:
# {1: 'Abhiraj', 2: 'Sahil', 3: 'Sumedh', 4: 'Krishna', 5: 'Rajveer'}

# %%
my_dict={
    "Name":"Abhiraj",
    "Roll no.": 3,
    "Devision":4,
}
key_list=list(my_dict.keys())
value_list=list(my_dict.values())
print("Keys:",key_list)
print("Values:",value_list)
# Out:
# Keys: ['Name', 'Roll no.', 'Devision']
# Values: ['Abhiraj', 3, 4]

# %%
list1=['Name', 'Roll no.', 'Devision']
list2=['Abhiraj', 3, 4]
my_dict=dict(zip(list1,list2))
print("Dictionary",my_dict)
# Out:
# Dictionary {'Name': 'Abhiraj', 'Roll no.': 3, 'Devision': 4}

# %%
my_dict={}
for i in range(1,6):
    my_dict[i]=float(input("Enter the Marks"))
total=sum(my_dict.values())
mean=total/len(my_dict)
print("Mean of all values",mean)
print("Dictionary",my_dict)
# Out:
# Enter the Marks 25
# Enter the Marks 24
# Enter the Marks 23
# Enter the Marks 22
# Enter the Marks 21
# Mean of all values 23.0
# Dictionary {1: 25.0, 2: 24.0, 3: 23.0, 4: 22.0, 5: 21.0}

# %%
my_dict={
    "Name":"Abhiraj",
    "Roll no.":42,
    "Devision":4,
    "Marks":[87,92,87,85,89]
}
sorted_dict=sorted(my_dict)
print("Sorted keys",sorted_dict)
# Out:
# Sorted keys ['Devision', 'Marks', 'Name', 'Roll no.']

# %%
students={
    "Abhiraj":96,
    "Sahil":94,
    "Sumedh":90,
    "Prachi":89,
    "Kushagra":99
}
highest_student=max(students,key=students.get)
print("student with highest marks:",highest_student)
print("highest marks:",students[highest_student])
# Out:
# student with highest marks: Kushagra
# highest marks: 99

# %%
numbers=[10,20,10,30,30,50,20,20,20,50]
frequency={}
for num in numbers:
    if num in frequency:
        frequency[num]=frequency[num]+1
    else:
        frequency[num]=1
print("Frequency of elements:",frequency)
# Out:
# Frequency of elements: {10: 2, 20: 4, 30: 2, 50: 2}

# %%
my_dict={
    "Abhiraj":96,
    "Sahil":94,
    "Sumedh":90,
    "Prachi":89,
    "Kushagra":99
}
sorted_dict=(dict(sorted(my_dict.items(),key=lambda item:item[1])))
print("Dictionary sorted by values:",sorted_dict)
# Out:
# Dictionary sorted by values: {'Prachi': 89, 'Sumedh': 90, 'Sahil': 94, 'Abhiraj': 96, 'Kushagra': 99}

# %%
my_dict={
    "Abhiraj":96,
    "Sahil":94,
    "Sumedh":90,
    "Prachi":89,
    "Kushagra":99
}
sorted_dict=(dict(sorted(my_dict.items(),key=lambda item:item[1],reverse=True)))
print("Dictionary sorted by values:",sorted_dict)
# Out:
# Dictionary sorted by values: {'Kushagra': 99, 'Abhiraj': 96, 'Sahil': 94, 'Sumedh': 90, 'Prachi': 89}
